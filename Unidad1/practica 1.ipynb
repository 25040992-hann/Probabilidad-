# %% [markdown]
# <a href="https://colab.research.google.com/github/25040992-hann/Probabilidad-/blob/main/Unidad1/practica%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadística
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Tiffany Hannay Guerrero
# ### Programa 1: estadística básica e histograma

# %%
from statistics import *

# %%
# lista de calificaciones del grupo de probabilidad y estadística
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupoa)
type(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# list

# %%
# Sacar la media de las calificaciones con una formula
promedio = sum(grupoa)/len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
# Utilizar la funcion mean que esta en la libreria statistics para sacar el promedio
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
# Detreminar el valor de la meidana con la funcion median
mediana = median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
# Determinar el valor de la moda con la funcion mode
moda = mode(grupoa)
print(moda)
# Out:
# 70

# %%
# En caso de que exista mas de una moda, se puede emplear la funcion multimode
# para sacar multiples modas que puedan existir
moda2 = multimode(grupoa)
print(moda2)
# Out:
# [70, 100]

# %%
# Definir una variablellamada tiempos100mts de tipo lista, que contiene los
# tiempos que tardaron los 10 alumnos para corre los 100 metros
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.20,
                 17.28]
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.2, 17.28]

# %%
# Usamos la funcion mean para determinar el tiempo promedio de la lista de valores
# Usar la funcion median para determinar la mediana de los tiempos
# Usar la funcion mode para determinar la moda de la lista de valores
print("el tiempo promedio de los corredores es de: ", mean(tiempos100mts))
print("la media del tiempo es de: ", median(tiempos100mts))
print("la moda de la lista de valores es: ", mode(tiempos100mts))
# Out:
# el tiempo promedio de los corredores es de:  17.34
# la media del tiempo es de:  17.240000000000002
# la moda de la lista de valores es:  15.1

# %%
# Libreria para generar numeros aleatorios
import random

# %%
fabrica1  = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [72.35, 73.29, 60.53, 55.15, 76.25, 51.83, 59.71, 88.33, 79.18, 57.86, 79.63, 61.77, 85.74, 56.39, 72.33, 93.01, 84.76, 78.43, 50.18, 95.22, 88.83, 80.23, 59.76, 50.94, 69.75, 61.27, 59.67, 99.14, 89.57, 64.97, 51.54, 71.58, 81.2, 73.69, 74.9, 61.63, 87.87, 68.8, 98.61, 60.9, 66.12, 56.56, 70.48, 65.44, 94.44, 76.82, 54.37, 70.54, 90.99, 96.2, 67.78, 63.96, 55.31, 70.53, 54.33, 96.43, 57.4, 67.32, 71.24, 87.18, 84.35, 50.97, 76.23, 55.64, 59.82, 98.85, 96.0, 96.83, 83.68, 56.66, 52.64, 91.98, 96.8, 54.96, 61.52, 63.32, 66.22, 73.73, 68.31, 78.66, 89.41, 68.76, 78.61, 75.39, 61.06, 97.67, 77.3, 64.37, 85.15, 92.96, 65.04, 95.99, 63.36, 97.94, 50.36, 57.88, 79.16, 84.12, 60.98, 92.12]

# %%
fabrica2  = []
for i in range(100):
  numero_aleatorio2 = round(random.uniform(70, 100), 2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [85.56, 96.5, 86.26, 93.03, 76.97, 70.72, 97.56, 91.57, 82.06, 77.63, 96.2, 80.75, 83.27, 89.29, 83.09, 92.85, 74.37, 81.79, 97.78, 70.76, 94.52, 94.71, 91.29, 83.27, 81.37, 90.79, 95.12, 82.35, 71.5, 97.81, 88.99, 90.08, 75.02, 86.94, 71.55, 89.26, 87.26, 90.39, 95.72, 99.82, 90.49, 87.94, 88.72, 87.08, 98.49, 93.42, 75.16, 81.1, 84.98, 77.39, 93.89, 91.64, 75.86, 74.06, 87.65, 74.87, 89.28, 91.87, 98.58, 76.24, 84.97, 85.69, 77.88, 83.72, 83.8, 73.94, 92.09, 71.93, 88.02, 99.72, 71.37, 95.43, 71.06, 89.24, 96.56, 89.33, 93.82, 96.7, 93.13, 70.92, 82.1, 94.0, 78.1, 87.99, 98.78, 78.74, 91.27, 87.83, 94.68, 86.38, 99.45, 98.65, 86.4, 89.0, 71.13, 81.71, 80.45, 92.42, 87.15, 90.86]

# %%
# Libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("producción diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'producción diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("producción diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'producción diaria de la fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("VALORES DE LA FABRICA 1")
print("la media es = ", media1)
print("la mediana es = ", mediana1)
print("la moda es = ", moda1)
# Out:
# VALORES DE LA FABRICA 1
# la media es =  73.2503
# la mediana es =  71.41
# la moda es =  72.35

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("VALORES DE LA FABRICA 2")
print("la media es = ", media2)
print("la mediana es = ", mediana2)
print("la moda es = ", moda2)
# Out:
# VALORES DE LA FABRICA 2
# la media es =  86.5089
# la mediana es =  87.88499999999999
# la moda es =  83.27

# %%
# Generar 2 subplot de 1 renglon po 2 columnas para desplegar los 2 histogramas
# una al lado de la otra
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()
