# %% [markdown]
# <a href="https://colab.research.google.com/github/25040992-hann/Probabilidad-/blob/main/Unidad1/practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadística
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Tiffany Hannay Guerrero
# ### Practica 2: maximo, minimo, rango y dispersión de datos

# %%
import random
import matplotlib.pyplot as plt
from statistics import*

# %%
#generar 100 numeros aleatorios que representan la producción
#en metros de tela de 100 días
fabrica1 = []
for i in range(100):
  numero_aleatorio =round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [82.95, 75.63, 59.19, 96.09, 98.36, 92.41, 68.96, 61.88, 90.63, 74.31, 53.21, 51.2, 97.5, 57.34, 96.41, 52.42, 75.78, 99.54, 75.26, 96.66, 59.93, 73.97, 59.04, 74.97, 91.12, 97.15, 55.97, 94.09, 79.83, 91.16, 95.45, 81.55, 96.9, 97.8, 61.18, 89.49, 85.84, 55.71, 51.73, 68.73, 77.15, 87.71, 76.34, 89.88, 81.78, 81.45, 57.94, 89.64, 95.0, 56.2, 98.94, 89.59, 68.26, 79.69, 97.79, 54.23, 80.75, 94.37, 64.49, 55.51, 83.26, 61.66, 71.07, 87.7, 57.31, 85.44, 86.59, 62.68, 77.76, 52.05, 77.78, 94.39, 74.34, 78.53, 81.95, 99.61, 70.39, 80.79, 88.28, 60.33, 72.75, 50.25, 82.18, 98.36, 87.88, 86.21, 68.95, 95.29, 67.84, 85.02, 69.37, 67.84, 96.53, 65.17, 72.07, 85.39, 87.36, 88.92, 78.0, 62.71]

# %%
#generar 100 numeros aleatorios que representan la producción
#en metros de tela de 100 días
fabrica2 = []
for i in range(100):
  numero_aleatorio =round(random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [96.75, 56.13, 93.07, 53.24, 77.71, 64.98, 73.15, 73.42, 87.61, 67.95, 58.36, 78.09, 59.99, 74.85, 87.32, 97.19, 71.96, 51.3, 74.38, 58.07, 73.83, 75.09, 82.86, 70.87, 64.08, 69.79, 91.68, 83.06, 70.76, 96.28, 80.63, 85.63, 58.66, 85.26, 82.17, 99.88, 86.73, 81.21, 83.62, 64.63, 76.2, 82.61, 52.35, 86.96, 89.45, 75.39, 89.57, 80.53, 52.13, 98.62, 77.73, 71.19, 62.27, 90.84, 61.23, 68.14, 80.61, 85.19, 75.65, 56.22, 59.37, 64.36, 93.14, 96.23, 65.96, 89.63, 76.98, 71.19, 81.29, 63.99, 92.26, 99.56, 68.77, 71.43, 55.14, 82.58, 73.49, 66.83, 58.91, 53.12, 97.95, 58.01, 79.39, 51.63, 60.4, 71.46, 84.18, 91.04, 56.79, 55.25, 75.53, 82.6, 94.14, 79.6, 95.2, 80.41, 69.96, 59.83, 69.98, 75.53]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 =stdev(fabrica1)
print("estadistica descriptiva de la fabrica 1 \n", "media =", media1,
      "\n mediana =", mediana1, "\n moda =", moda1, "\n maximo =", maximo1,
      "\n minimo =", minimo1, "\n rango =", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# estadistica descriptiva de la fabrica 1
#  media = 77.9405
#  mediana = 79.75999999999999
#  moda = 98.36
#  maximo = 99.61
#  minimo = 50.25
#  rango = 49.36
# 14.649162790226118

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 =stdev(fabrica2)
print("estadistica descriptiva de la fabrica 2 \n", "media =", media2,
      "\n mediana =", mediana2, "\n moda =", moda2, "\n maximo =", maximo2,
      "\n minimo =", minimo2, "\n rango =", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# estadistica descriptiva de la fabrica 2
#  media = 75.2823
#  mediana = 75.46000000000001
#  moda = 71.19
#  maximo = 99.88
#  minimo = 51.3
#  rango = 48.58
# 13.33660595102552

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = 'black')
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, lebel=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2, label=f'desv. estandar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2)

plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title("produccion de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = 'black')
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, lebel=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. estandar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2)

plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title("produccion de la fabrica 2")
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
#la densidad grafica se basa en una forma de visualizar la distribucion de datos en
#un intervalo o periodo de timepo continuo.
#se basa en un histograma que usa el suavizado de kernel para trazar valores,
#lo que permite obtener distribuciones mas suabes al reducir el ruido.
#una curva de densidad muetra la ubicacion de la media y la mediana de una distribucion
sns.histplot( x = fabrica1, kde = True, kde_kws = {'bw_adjust': 0.5}, bins=10)
# Out:
# <Axes: ylabel='Count'>
