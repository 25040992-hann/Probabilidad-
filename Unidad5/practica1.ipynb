# %% [markdown]
# <a href="https://colab.research.google.com/github/25040992-hann/Probabilidad-/blob/main/Unidad5/practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
periodos = [2018, 2019, 2020, 2021, 2022, 2023]
inversion = np. array( [2, 3, 5, 4, 11, 5] ).reshape(-1, 1)
ganancias = [20, 25, 34, 30, 40, 31]

modelo = LinearRegression()
modelo.fit(inversion, ganancias)

ganancia_2024 = modelo.predict( [[8]])

print("La ganancia esperada para el año 2024 es de: ", ganancia_2024[0])
print("Coeficiente de la pendiente (m): ", modelo.coef_[0])
print("Intercepcion de la recta (b): ", modelo.intercept_)
# Out:
# La ganancia esperada para el año 2024 es de:  36.0
# Coeficiente de la pendiente (m):  2.0000000000000004
# Intercepcion de la recta (b):  20.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6, 4))

inversion = [2, 3, 5, 4, 11, 5]
ganancias = [20, 25, 34, 30, 40, 31]

sns.scatterplot(x = inversion, y = ganancias)
plt.title('Diagrama de Dispersión de Inversión vs. Ganacias')
plt.xlabel('Inversión (millones)')
plt.ylabel('Ganancias (millones)')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6, 4))

inverison = [2, 3, 5, 4, 11, 5]
ganancias = [20, 25, 34, 30, 40, 31]

sns.set(style="whitegrid")
sns.regplot(x=inversion, y=ganancias, scatter=True, color='blue')
plt.title('Diagrama de Disperción con Lineas de Regresión')
plt.xlabel('Inversión (millones)')
plt.ylabel('Gnanacias (millones)')
plt.grid(True)
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
publicidad = np.array([2, 3, 5, 4, 11, 5]).reshape(-1, 1)
ganancias = ([20, 25, 34, 20, 40, 31])

modelo = LinearRegression()
modelo.fit(publicidad, ganancias)

inversion_prediccion = np.array([[8]])
ganancia_predicha =modelo.predict(inversion_prediccion)

print("La ganancia esperada para la inverison de 8 en publicidad es: ", ganancia_predicha[0])
print("Valor de la intercepción", modelo.intercept_)
print("Valor de la pendiente", modelo.coef_)

plt.figure(figsize=(6, 5))
plt.scatter(publicidad, ganancias, color='blue', label='Datos')
plt.plot(publicidad, modelo.predict(publicidad), color='red', label='Lineal de Regresión')
plt.scatter(inversion_prediccion, ganancia_predicha, color='green', marker='x', s=100, label='Predicción(8, {0:.2f})'.format(ganancia_predicha[0]))
plt.title('Pronostico de ganancias a partir de la inversón en publicidad')
plt.xlabel('Inversión de publicidad (millones)')
plt.ylabel('Ganancias anuales (millones)')
plt.grid(True)
plt.show()
# Out:
# La ganancia esperada para la inverison de 8 en publicidad es:  34.93333333333334
# Valor de la intercepción 17.33333333333333
# Valor de la pendiente [2.2]
