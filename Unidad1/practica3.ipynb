# %% [markdown]
# <a href="https://colab.research.google.com/github/25040992-hann/Probabilidad-/blob/main/Unidad1/practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadística
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Tiffany Hannay Guerrero
# ### Practica 3: tablas de frecuencias

# %%
#basado en el libro estadistica para administracion pagina 12
#creamos una lista vacia que representa la edad de 100 personas
import random
edades = []
#hacemos un ciclo para generar 100 numneros aleatorios que representan la edad de las personas
for i in range (100):
#generaamos un numero aleatorio con la funcion randint y lo guardamos en la variable
#nunero_aleatorio
 numero_aleatorio = random.randint(18,70)
#agregamos el numero aleatorio a la lista de valores
 edades.append(numero_aleatorio)
print(edades)
# Out:
# [44, 61, 46, 18, 62, 20, 61, 43, 38, 52, 45, 26, 23, 51, 59, 56, 37, 57, 19, 44, 69, 49, 62, 40, 45, 54, 24, 20, 51, 69, 27, 33, 35, 53, 57, 52, 30, 67, 58, 46, 22, 66, 64, 29, 67, 22, 40, 32, 58, 66, 19, 36, 26, 34, 26, 34, 46, 54, 43, 44, 41, 40, 20, 34, 45, 19, 46, 43, 35, 52, 66, 53, 38, 60, 23, 21, 67, 54, 26, 32, 57, 55, 37, 45, 47, 44, 58, 44, 31, 24, 55, 22, 26, 20, 60, 35, 31, 55, 31, 50]

# %%
import pandas as pd

# %%
#crear un DataFrame de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    44
# 1    61
# 2    46
# 3    18
# 4    62

# %%
#calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

#imprimir la tabla de distribucion de frecuencias
print("Tabla de Distribución de Frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 30    18           1
# 11    19           3
# 2     20           4
# 40    21           1
# 17    22           3
# 21    23           2
# 28    24           2
# 1     26           5
# 34    27           1
# 39    29           1
# 36    30           1
# 14    31           3
# 29    32           2
# 31    33           1
# 13    34           3
# 7     35           3
# 37    36           1
# 27    37           2
# 23    38           2
# 8     40           3
# 41    41           1
# 5     43           3
# 0     44           5
# 4     45           4
# 3     46           4
# 42    47           1
# 35    49           1
# 43    50           1
# 26    51           2
# 6     52           3
# 24    53           2
# 9     54           3
# 15    55           3
# 32    56           1
# 10    57           3
# 16    58           3
# 33    59           1
# 20    60           2
# 19    61           2
# 22    62           2
# 38    64           1
# 12    66           3
# 18    67           3
# 25    69           2

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 30    18           1           0.01
# 11    19           3           0.03
# 2     20           4           0.04
# 40    21           1           0.01
# 17    22           3           0.03
# 21    23           2           0.02
# 28    24           2           0.02
# 1     26           5           0.05
# 34    27           1           0.01
# 39    29           1           0.01
# 36    30           1           0.01
# 14    31           3           0.03
# 29    32           2           0.02
# 31    33           1           0.01
# 13    34           3           0.03
# 7     35           3           0.03
# 37    36           1           0.01
# 27    37           2           0.02
# 23    38           2           0.02
# 8     40           3           0.03
# 41    41           1           0.01
# 5     43           3           0.03
# 0     44           5           0.05
# 4     45           4           0.04
# 3     46           4           0.04
# 42    47           1           0.01
# 35    49           1           0.01
# 43    50           1           0.01
# 26    51           2           0.02
# 6     52           3           0.03
# 24    53           2           0.02
# 9     54           3           0.03
# 15    55           3           0.03
# 32    56           1           0.01
# 10    57           3           0.03
# 16    58           3           0.03
# 33    59           1           0.01
# 20    60           2           0.02
# 19    61           2           0.02
# 22    62           2           0.02
# 38    64           1           0.01
# 12    66           3           0.03
# 18    67           3           0.03
# 25    69           2           0.02

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 30    18           1           0.01              1.0
# 11    19           3           0.03              3.0
# 2     20           4           0.04              4.0
# 40    21           1           0.01              1.0
# 17    22           3           0.03              3.0
# 21    23           2           0.02              2.0
# 28    24           2           0.02              2.0
# 1     26           5           0.05              5.0
# 34    27           1           0.01              1.0
# 39    29           1           0.01              1.0
# 36    30           1           0.01              1.0
# 14    31           3           0.03              3.0
# 29    32           2           0.02              2.0
# 31    33           1           0.01              1.0
# 13    34           3           0.03              3.0
# 7     35           3           0.03              3.0
# 37    36           1           0.01              1.0
# 27    37           2           0.02              2.0
# 23    38           2           0.02              2.0
# 8     40           3           0.03              3.0
# 41    41           1           0.01              1.0
# 5     43           3           0.03              3.0
# 0     44           5           0.05              5.0
# 4     45           4           0.04              4.0
# 3     46           4           0.04              4.0
# 42    47           1           0.01              1.0
# 35    49           1           0.01              1.0
# 43    50           1           0.01              1.0
# 26    51           2           0.02              2.0
# 6     52           3           0.03              3.0
# 24    53           2           0.02              2.0
# 9     54           3           0.03              3.0
# 15    55           3           0.03              3.0
# 32    56           1           0.01              1.0
# 10    57           3           0.03              3.0
# 16    58           3           0.03              3.0
# 33    59           1           0.01              1.0
# 20    60           2           0.02              2.0
# 19    61           2           0.02              2.0
# 22    62           2           0.02              2.0
# 38    64           1           0.01              1.0
# 12    66           3           0.03              3.0
# 18    67           3           0.03              3.0
# 25    69           2           0.02              2.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 30    18           1           0.01              1.0               1
# 11    19           3           0.03              3.0               4
# 2     20           4           0.04              4.0               8
# 40    21           1           0.01              1.0               9
# 17    22           3           0.03              3.0              12
# 21    23           2           0.02              2.0              14
# 28    24           2           0.02              2.0              16
# 1     26           5           0.05              5.0              21
# 34    27           1           0.01              1.0              22
# 39    29           1           0.01              1.0              23
# 36    30           1           0.01              1.0              24
# 14    31           3           0.03              3.0              27
# 29    32           2           0.02              2.0              29
# 31    33           1           0.01              1.0              30
# 13    34           3           0.03              3.0              33
# 7     35           3           0.03              3.0              36
# 37    36           1           0.01              1.0              37
# 27    37           2           0.02              2.0              39
# 23    38           2           0.02              2.0              41
# 8     40           3           0.03              3.0              44
# 41    41           1           0.01              1.0              45
# 5     43           3           0.03              3.0              48
# 0     44           5           0.05              5.0              53
# 4     45           4           0.04              4.0              57
# 3     46           4           0.04              4.0              61
# 42    47           1           0.01              1.0              62
# 35    49           1           0.01              1.0              63
# 43    50           1           0.01              1.0              64
# 26    51           2           0.02              2.0              66
# 6     52           3           0.03              3.0              69
# 24    53           2           0.02              2.0              71
# 9     54           3           0.03              3.0              74
# 15    55           3           0.03              3.0              77
# 32    56           1           0.01              1.0              78
# 10    57           3           0.03              3.0              81
# 16    58           3           0.03              3.0              84
# 33    59           1           0.01              1.0              85
# 20    60           2           0.02              2.0              87
# 19    61           2           0.02              2.0              89
# 22    62           2           0.02              2.0              91
# 38    64           1           0.01              1.0              92
# 12    66           3           0.03              3.0              95
# 18    67           3           0.03              3.0              98
# 25    69           2           0.02              2.0             100

# %%
#importar la libreria math de funciones matematicas
import math

# %%
#volvemos a usar la lista de edades
print(edades)
# Out:
# [44, 61, 46, 18, 62, 20, 61, 43, 38, 52, 45, 26, 23, 51, 59, 56, 37, 57, 19, 44, 69, 49, 62, 40, 45, 54, 24, 20, 51, 69, 27, 33, 35, 53, 57, 52, 30, 67, 58, 46, 22, 66, 64, 29, 67, 22, 40, 32, 58, 66, 19, 36, 26, 34, 26, 34, 46, 54, 43, 44, 41, 40, 20, 34, 45, 19, 46, 43, 35, 52, 66, 53, 38, 60, 23, 21, 67, 54, 26, 32, 57, 55, 37, 45, 47, 44, 58, 44, 31, 24, 55, 22, 26, 20, 60, 35, 31, 55, 31, 50]

# %%
#crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     44
# 1     61
# 2     46
# 3     18
# 4     62
# ..   ...
# 95    35
# 96    31
# 97    55
# 98    31
# 99    50
#
# [100 rows x 1 columns]

# %%
#calcular el numero de intervalos utilizando la regla de Struges
n = len(edades)
K = int( 1 + math.log2(n))
print("valor de n = ", n, "\nNúmero de intervalos = ", K)
# Out:
# valor de n =  100
# Número de intervalos =  7

# %%
#crear tabla de frecuencia

tabla_frecuencia = pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (39.857, 47.143]    21
# 1  (17.948, 25.286]    16
# 2  (54.429, 61.714]    15
# 3  (25.286, 32.571]    13
# 4  (32.571, 39.857]    12
# 5  (47.143, 54.429]    12
# 6    (61.714, 69.0]    11

# %%
#ordenar la tabla de frecuencias por intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 1  (17.948, 25.286]    16
# 3  (25.286, 32.571]    13
# 4  (32.571, 39.857]    12
# 0  (39.857, 47.143]    21
# 5  (47.143, 54.429]    12
# 2  (54.429, 61.714]    15
# 6    (61.714, 69.0]    11

# %%
#generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

#mostrar la tabla frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 1  (17.948, 25.286]    16      0.16       16.0       16         0.16
# 3  (25.286, 32.571]    13      0.13       13.0       29         0.29
# 4  (32.571, 39.857]    12      0.12       12.0       41         0.41
# 0  (39.857, 47.143]    21      0.21       21.0       62         0.62
# 5  (47.143, 54.429]    12      0.12       12.0       74         0.74
# 2  (54.429, 61.714]    15      0.15       15.0       89         0.89
# 6    (61.714, 69.0]    11      0.11       11.0      100         1.00
#
#    Frec Porc Ac
# 1          16.0
# 3          29.0
# 4          41.0
# 0          62.0
# 5          74.0
# 2          89.0
# 6         100.0

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
#crear un histograma basado en la tabla de frecuencias
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
