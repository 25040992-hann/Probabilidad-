# %% [markdown]
# <a href="https://colab.research.google.com/github/25040992-hann/Probabilidad-/blob/main/Unidad3/practica8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
x = [0, 1, 2, 3, 4, 5]
p = [0.05, 0.10, 0.25, 0.30, 0.20, 0.10]

print("Suma de probabilidades: ", sum(p))

plt.stem(x, p)
plt.title("Distribución de Probabilidad")
plt.xlabel("Productos")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Suma de probabilidades:  1.0

# %%
x = [0, 1, 2, 3, 4, 5]
p = [0.05, 0.10, 0.25, 0.30, 0.20, 0.10]

valor_esperado = 0

for i in range(len(x)):
  xi = x[i]
  pi = p[i]
  producto = xi * pi
  valor_esperado += producto

  print(f"x = {xi}, p = {pi}, x*p = {producto:.2f}")
print(f"\nValor esperado (Esperanza): {valor_esperado:.2f}")
# Out:
# x = 0, p = 0.05, x*p = 0.00
# x = 1, p = 0.1, x*p = 0.10
# x = 2, p = 0.25, x*p = 0.50
# x = 3, p = 0.3, x*p = 0.90
# x = 4, p = 0.2, x*p = 0.80
# x = 5, p = 0.1, x*p = 0.50
#
# Valor esperado (Esperanza): 2.80

# %%
x = [0, 1, 2, 3, 4, 5]
p = [0.05, 0.10, 0.25, 0.30, 0.20, 0.10]

esperanza = 0
for i in range(len(x)):
  esperanza+=  x[i] * p[i]

esperanza_cuadrada = 0
for i in  range(len(x)):
  esperanza_cuadrada += (x[i] ** 2) * p[i]

varianza = esperanza_cuadrada - esperanza**2
desviacion = math.sqrt(varianza)

print(f"E(x) = {esperanza:.2f}")
print(f"E(x^2) = {esperanza_cuadrada:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviación Estándar = {desviacion:.2f}")
# Out:
# E(x) = 2.80
# E(x^2) = 9.50
# Varianza = 1.66
# Desviación Estándar = 1.29

# %%
x = [0, 1, 2, 3, 4, 5]
p = [0.05, 0.10, 0.25, 0.30, 0.20, 0.10]

F = np.cumsum(p)

for xi, fi in zip(x, F):
  print(f"F({xi}) = {fi:.2f}")

plt.step(x, F, where='post')
plt.title("Función de Distribución Acumulada (FDA)")
plt.xlabel("Productos")
plt.ylabel("Probabilidad acumulada")
plt.grid(True)
plt.ylim(0, 1.05)
plt.show()
# Out:
# F(0) = 0.05
# F(1) = 0.15
# F(2) = 0.40
# F(3) = 0.70
# F(4) = 0.90
# F(5) = 1.00

# %% [markdown]
# ##Interpretación de Resultados
# -> Según el valor esperado que se calculo, en promedio se espera vender aproximadamente 3 unidades a la semana.
#
# -> La desviación estandar indica que la demanda tiene una variación moderada, las ventas no suelen ser muy altas pero tampoco se van a puntos bajos, no se mantienen completamente estables pero tampoco completamente volaátiles.
