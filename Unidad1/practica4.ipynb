# %% [markdown]
# <a href="https://colab.research.google.com/github/25040992-hann/Probabilidad-/blob/main/Unidad1/practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadística
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Tiffany Hannay Guerrero
# ### Practica 4: Diagrama de cajas y bigotes

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [63.94, 60.53, 98.19, 88.71, 67.98, 76.82, 92.76, 50.45, 75.42, 84.16, 52.6, 96.19, 74.57, 96.43, 60.31, 87.73, 87.99, 70.02, 79.14, 75.37, 77.82, 67.14, 82.71, 61.07, 67.07, 60.56, 57.39, 57.67, 89.17, 78.0, 74.72, 61.78, 70.94, 86.39, 70.89, 51.12, 76.0, 87.0, 62.97, 52.48, 62.32, 60.16, 63.12, 50.59, 86.21, 67.41, 97.24, 53.72, 89.01, 56.01, 85.81, 76.75, 50.2, 66.8, 64.22, 70.71, 79.65, 78.99, 64.97, 50.7, 95.44, 53.08, 61.35, 56.67, 73.89, 99.55, 64.35, 98.31, 88.84, 97.52, 60.59, 77.64, 94.82, 50.39, 68.7, 81.05, 92.85, 82.78, 59.96, 66.03, 51.8, 85.77, 67.29, 69.65, 74.77, 99.27, 66.35, 85.7, 81.97, 85.92, 65.34, 96.89, 83.04, 54.9, 57.8, 82.51, 61.6, 70.2, 66.15, 98.47]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(40, 93), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [79.34, 80.16, 68.61, 54.33, 69.86, 49.45, 73.87, 82.27, 46.2, 71.18, 92.5, 67.43, 79.86, 62.4, 71.85, 49.65, 88.62, 49.46, 64.49, 66.81, 90.6, 50.79, 77.25, 81.27, 43.55, 55.77, 78.71, 59.47, 81.72, 75.22, 74.67, 90.87, 57.62, 53.92, 72.44, 64.02, 65.74, 42.61, 59.6, 53.31, 69.06, 89.46, 54.81, 42.08, 65.45, 88.46, 76.13, 51.2, 40.43, 74.51, 43.83, 49.9, 47.74, 69.02, 92.15, 41.0, 72.94, 58.51, 62.03, 60.3, 49.73, 56.45, 44.49, 43.49, 83.51, 90.71, 85.08, 45.08, 87.79, 47.62, 84.47, 67.41, 61.38, 50.88, 79.15, 70.61, 69.43, 45.17, 88.14, 51.06, 68.25, 72.77, 56.98, 51.86, 47.7, 66.46, 53.15, 87.87, 83.8, 84.21, 55.28, 66.51, 62.32, 85.93, 84.41, 44.89, 65.91, 58.27, 70.71, 70.65]

# %%
plt.boxplot(fabrica1)
plt.ylabel('Produccion en mts')
plt.title('Produccion de la fabrica 1')
plt.show()

# %%
plt.boxplot(fabrica2)
plt.ylabel('Produccuon en mts')
plt.title('Produccion de la fabrica 2')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True, #Alineacion vertical
                     patch_artist=True) #Rellenar con color
ax1.set_title('Produccion fabrica 1')

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, #Alineacion vertical
                     patch_artist=True) #Rellenar con color

ax2.set_title('Produccion fabrica 2')
plt.show()

# %%
#Insertar un valor de 150 a la fabrica1, será un valor atipico
fabrica1.append(150)
print(fabrica1)
# Out:
# [63.94, 60.53, 98.19, 88.71, 67.98, 76.82, 92.76, 50.45, 75.42, 84.16, 52.6, 96.19, 74.57, 96.43, 60.31, 87.73, 87.99, 70.02, 79.14, 75.37, 77.82, 67.14, 82.71, 61.07, 67.07, 60.56, 57.39, 57.67, 89.17, 78.0, 74.72, 61.78, 70.94, 86.39, 70.89, 51.12, 76.0, 87.0, 62.97, 52.48, 62.32, 60.16, 63.12, 50.59, 86.21, 67.41, 97.24, 53.72, 89.01, 56.01, 85.81, 76.75, 50.2, 66.8, 64.22, 70.71, 79.65, 78.99, 64.97, 50.7, 95.44, 53.08, 61.35, 56.67, 73.89, 99.55, 64.35, 98.31, 88.84, 97.52, 60.59, 77.64, 94.82, 50.39, 68.7, 81.05, 92.85, 82.78, 59.96, 66.03, 51.8, 85.77, 67.29, 69.65, 74.77, 99.27, 66.35, 85.7, 81.97, 85.92, 65.34, 96.89, 83.04, 54.9, 57.8, 82.51, 61.6, 70.2, 66.15, 98.47, 150]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True, #Vertical box alignment
                     patch_artist=True) #fill with color
ax1.set_title('Produccion fabrica 1')

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, #Vertical box alignment
                     patch_artist=True) #fill with color

ax2.set_title('Produccion fabrica 2')
plt.show()

# %%
#Agregar ax1.set_ylim(0, 160) para garantizar que ambos graficos usen la
#misma escala vertical, faciltando la comparación visual.
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 5))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True, #Alineacion vertical t
                     patch_artist=True) #Rellenar con color
ax1.set_title('Produccion fabrica 1')
ax1.set_ylim(30, 160) #Escala uniforme de 0 a 160

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, #Alineacion vertical t
                     patch_artist=True) #Rellenar con color

ax2.set_title('Produccion fabrica 2')
ax2.set_ylim(30, 160) #Escala uniforme de 0 a 160
plt.show()
