# %% [markdown]
# <a href="https://colab.research.google.com/github/25040992-hann/Probabilidad-/blob/main/Unidad1/practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadística
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Tiffany Hannay Guerrero
# ### Practica 2: maximo, minimo, rango y dispersión de datos

# %%
import random
import matplotlib.pyplot as plt
from statistics import*

# %%
#generar 100 numeros aleatorios que representan la producción
#en metros de tela de 100 días
fabrica1 = []
for i in range(100):
  numero_aleatorio =round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [85.66, 93.36, 89.09, 64.68, 55.88, 92.17, 65.9, 95.72, 75.32, 55.39, 82.35, 73.72, 77.28, 63.39, 61.17, 84.52, 52.25, 74.64, 61.38, 99.82, 65.2, 90.38, 56.38, 66.08, 58.47, 74.58, 79.67, 86.72, 65.28, 65.54, 77.05, 92.02, 60.77, 93.87, 89.75, 58.98, 52.87, 91.6, 94.55, 55.25, 93.91, 75.51, 96.95, 91.11, 97.95, 71.63, 69.31, 77.18, 78.2, 70.8, 86.97, 57.24, 54.02, 59.47, 53.36, 97.19, 84.24, 93.62, 78.1, 63.22, 98.81, 88.13, 97.25, 59.8, 97.8, 91.38, 84.02, 72.16, 57.62, 80.96, 57.23, 65.01, 55.06, 75.87, 62.79, 87.61, 65.1, 62.2, 78.08, 51.23, 87.11, 90.32, 51.46, 63.96, 83.85, 65.93, 80.65, 88.57, 96.02, 86.75, 74.11, 64.76, 92.71, 70.95, 65.65, 53.81, 81.06, 97.56, 81.87, 57.96]

# %%
#generar 100 numeros aleatorios que representan la producción
#en metros de tela de 100 días
fabrica2 = []
for i in range(100):
  numero_aleatorio =round(random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [89.51, 91.33, 96.35, 94.08, 96.24, 55.15, 73.95, 76.51, 98.98, 89.61, 73.55, 85.34, 80.23, 56.19, 86.51, 97.86, 88.13, 84.53, 63.14, 96.76, 80.08, 54.35, 52.13, 83.95, 54.65, 87.36, 55.21, 93.62, 64.48, 82.38, 86.34, 59.74, 85.2, 73.79, 58.72, 97.36, 56.08, 93.37, 88.99, 56.87, 99.27, 84.54, 86.38, 72.09, 81.39, 66.75, 51.52, 78.67, 86.68, 79.79, 99.25, 85.67, 57.03, 73.99, 50.64, 97.17, 84.42, 52.85, 79.7, 97.48, 59.43, 95.09, 65.46, 89.73, 72.01, 83.32, 55.55, 53.96, 58.54, 79.74, 72.33, 68.27, 90.87, 57.41, 93.77, 52.7, 53.66, 91.79, 77.72, 81.36, 83.13, 97.5, 69.93, 52.18, 98.97, 94.42, 92.1, 76.98, 93.13, 54.27, 60.65, 56.05, 58.85, 67.56, 95.26, 60.33, 85.71, 86.46, 96.08, 73.51]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 =stdev(fabrica1)
print("estadistica descriptiva de la fabrica 1 \n", "media =", media1,
      "\n mediana =", mediana1, "\n moda =", moda1, "\n maximo =", maximo1,
      "\n minimo =", minimo1, "\n rango =", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# estadistica descriptiva de la fabrica 1
#  media = 75.5185
#  mediana = 75.69
#  moda = 85.66
#  maximo = 99.82
#  minimo = 51.23
#  rango = 48.589999999999996
# 14.638446706180849

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 =stdev(fabrica2)
print("estadistica descriptiva de la fabrica 2 \n", "media =", media2,
      "\n mediana =", mediana2, "\n moda =", moda2, "\n maximo =", maximo2,
      "\n minimo =", minimo2, "\n rango =", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# estadistica descriptiva de la fabrica 2
#  media = 77.0968
#  mediana = 80.155
#  moda = 89.51
#  maximo = 99.27
#  minimo = 50.64
#  rango = 48.629999999999995
# 15.596887469859965
